# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\user\Desktop\DATA SCIENCE CLASS\DataScienceClass\exam (1).csv")

# %%
df.columns
# Out:
# Index(['hours_study', 'attendance', 'score'], dtype='object')

# %%
df.describe()
# Out:
#        hours_study   attendance        score
# count  2000.000000  2000.000000  2000.000000
# mean      3.535500    74.678500    15.094100
# std       1.709152    14.410863     3.210602
# min       1.000000    50.000000     8.130000
# 25%       2.000000    62.000000    12.530000
# 50%       4.000000    75.000000    15.130000
# 75%       5.000000    87.000000    17.730000
# max       6.000000    99.000000    21.930000

# %%
df.hours_study.plot(kind='box')
plt.title('A Box describing students hours of study')
plt.ylabel('hours of study')

plt.show()

# %%
df.hours_study.plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.attendance.plot(kind='hist', bins=50)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.hours_study.unique()
# Out:
# array([6, 5, 4, 3, 1, 2], dtype=int64)

# %%
df.attendance.describe()
# Out:
# count    2000.000000
# mean       74.678500
# std        14.410863
# min        50.000000
# 25%        62.000000
# 50%        75.000000
# 75%        87.000000
# max        99.000000
# Name: attendance, dtype: float64

# %%
df.attendance.plot(kind='box')
plt.title('A whisker plot showing the distribution of attendance')
plt.ylabel('Attendance_score');

# %%
df.plot(x='attendance',y='hours_study',kind='scatter')
# Out:
# <Axes: xlabel='attendance', ylabel='hours_study'>

# %%
df.attendance.corr(df.hours_study)
# Out:
# 0.016681395453494098

# %%
df.attendance.corr(df.score)
# Out:
# 0.9048089574549261

# %%
df.plot(x='score',y='attendance', kind='scatter')
# Out:
# <Axes: xlabel='score', ylabel='attendance'>

# %%
sns.scatterplot(data=df,y='attendance',x='score', hue='hours_study');

# %%
sns.scatterplot(data=df,y='attendance',x='score', size='hours_study');

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
sns.barplot(df,x='hours_study',y='attendance')
# Out:
# <Axes: xlabel='hours_study', ylabel='attendance'>

# %%
df.attendance
# Out:
# 0       87
# 1       99
# 2       51
# 3       62
# 4       67
#         ..
# 1995    83
# 1996    85
# 1997    99
# 1998    51
# 1999    54
# Name: attendance, Length: 2000, dtype: int64

# %%
df['label']=df.attendance%2
df
# Out:
#       hours_study  attendance  score  label
# 0               6          87  19.53      1
# 1               5          99  21.13      1
# 2               4          51  10.73      1
# 3               5          62  13.73      0
# 4               3          67  13.13      1
# ...           ...         ...    ...    ...
# 1995            6          83  18.73      1
# 1996            2          85  15.93      1
# 1997            2          99  18.73      1
# 1998            4          51  10.73      1
# 1999            1          54   8.93      0
#
# [2000 rows x 4 columns]

# %%
sns.scatterplot(data=df,y='attendance',x='score', size='hours_study',hue='label'); #4 dimension plot

# %%
sns.violinplot(df,y='attendance', x='hours_study')
# Out:
# <Axes: xlabel='hours_study', ylabel='attendance'>

# %%
sns.boxplot(df,y='attendance', x='hours_study')
# Out:
# <Axes: xlabel='hours_study', ylabel='attendance'>
