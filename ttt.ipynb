# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\user\Downloads\framingham (3).csv")
df
# Out:
#         male  age      education currentSmoker  cigsPerDay BPMeds  \
# 0       Male   39      post grad            No         0.0     No
# 1     Female   46  Secondary Edu            No         0.0     No
# 2       Male   48    Primary Edu           Yes        20.0     No
# 3     Female   61   Tertiary Edu           Yes        30.0     No
# 4     Female   46   Tertiary Edu           Yes        23.0     No
# ...      ...  ...            ...           ...         ...    ...
# 4235  Female   48  Secondary Edu           Yes        20.0    NaN
# 4236  Female   44    Primary Edu           Yes        15.0     No
# 4237  Female   52  Secondary Edu            No         0.0     No
# 4238    Male   40   Tertiary Edu            No         0.0     No
# 4239  Female   39   Tertiary Edu           Yes        30.0     No
#
#      prevalentStroke prevalentHyp diabetes  totChol  sysBP  diaBP    BMI  \
# 0                 No           No       No    195.0  106.0   70.0  26.97
# ...

# %%
df.isnull().sum()
# Out:
# male                 0
# age                  0
# education          105
# currentSmoker        0
# cigsPerDay          29
# BPMeds              53
# prevalentStroke      0
# prevalentHyp         0
# diabetes             0
# totChol             50
# sysBP                0
# diaBP                0
# BMI                 19
# heartRate            1
# glucose            388
# TenYearCHD           0
# dtype: int64

# %%
def missing(col_name):
    if df.dtypes[col_name]=='object':
        replace_val=df[col_name].mode()[0]
    elif df[col_name].std() > df[col_name].mean():    #GENERAL CODE COMBINED
        replace_val=df[col_name].median()
    else:
        replace_val=df[col_name].mean()
    df[col_name].fillna(replace_val, inplace= True)
missing('glucose')
missing('cigsPerDay')
missing('education')
missing('BPMeds')
missing('totChol')
missing('heartRate')
missing('BMI')

# %%
df.isnull().sum()
# Out:
# male               0
# age                0
# education          0
# currentSmoker      0
# cigsPerDay         0
# BPMeds             0
# prevalentStroke    0
# prevalentHyp       0
# diabetes           0
# totChol            0
# sysBP              0
# diaBP              0
# BMI                0
# heartRate          0
# glucose            0
# TenYearCHD         0
# dtype: int64
