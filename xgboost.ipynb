# %%
import pandas as pd

# %%
from sklearn.model_selection import train_test_split

# %%
from catboost import CatBoostRegressor

# %%
from xgboost import XGBoostRegressor
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from xgboost import XGBoostRegressor
#
# ImportError: cannot import name 'XGBoostRegressor' from 'xgboost' (C:\Users\user\AppData\Roaming\Python\Python311\site-packages\xgboost\__init__.py)

# %%
df=pd.read_csv(r'C:\Users\user\Downloads\Housing_dataset_train.csv')

# %%
def missing (df,missing_col):
