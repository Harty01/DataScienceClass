# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression

# %%
df=pd.read_csv(r"C:\Users\user\Downloads\new_framingham.csv")

# %%
df
# Out:
#         male  age      education currentSmoker  cigsPerDay BPMeds  \
# 0       Male   39      post grad            No         0.0     No
# 1     Female   46  Secondary Edu            No         0.0     No
# 2       Male   48    Primary Edu           Yes        20.0     No
# 3     Female   61   Tertiary Edu           Yes        30.0     No
# 4     Female   46   Tertiary Edu           Yes        23.0     No
# ...      ...  ...            ...           ...         ...    ...
# 4235  Female   48  Secondary Edu           Yes        20.0    NaN
# 4236  Female   44    Primary Edu           Yes        15.0     No
# 4237  Female   52  Secondary Edu            No         0.0     No
# 4238    Male   40   Tertiary Edu            No         0.0     No
# 4239  Female   39   Tertiary Edu           Yes        30.0     No
#
#      prevalentStroke prevalentHyp diabetes  totChol  sysBP  diaBP    BMI  \
# 0                 No           No       No    195.0  106.0   70.0  26.97
# ...

# %%
# for i,gender in enumerate (df["male"]):
#     print(i,gender)
#     if gender =='Female':
#         df['male']=0
#     elif gender== 'Male':
#         df['male']=1

# %%
df
# Out:
#         male  age      education currentSmoker  cigsPerDay BPMeds  \
# 0       Male   39      post grad            No         0.0     No
# 1     Female   46  Secondary Edu            No         0.0     No
# 2       Male   48    Primary Edu           Yes        20.0     No
# 3     Female   61   Tertiary Edu           Yes        30.0     No
# 4     Female   46   Tertiary Edu           Yes        23.0     No
# ...      ...  ...            ...           ...         ...    ...
# 4235  Female   48  Secondary Edu           Yes        20.0    NaN
# 4236  Female   44    Primary Edu           Yes        15.0     No
# 4237  Female   52  Secondary Edu            No         0.0     No
# 4238    Male   40   Tertiary Edu            No         0.0     No
# 4239  Female   39   Tertiary Edu           Yes        30.0     No
#
#      prevalentStroke prevalentHyp diabetes  totChol  sysBP  diaBP    BMI  \
# 0                 No           No       No    195.0  106.0   70.0  26.97
# ...

# %%
df.BPMeds.unique()
# Out:
# array(['No', 'Yes', nan], dtype=object)

# %%
# for i,x in enumerate (df['male']):
#     if x== 'Female':
#         df['male'][i]=0
#     elif x == 'Male':
#         df['male'][i]=1

# %%
df
# Out:
#         male  age      education currentSmoker  cigsPerDay BPMeds  \
# 0       Male   39      post grad            No         0.0     No
# 1     Female   46  Secondary Edu            No         0.0     No
# 2       Male   48    Primary Edu           Yes        20.0     No
# 3     Female   61   Tertiary Edu           Yes        30.0     No
# 4     Female   46   Tertiary Edu           Yes        23.0     No
# ...      ...  ...            ...           ...         ...    ...
# 4235  Female   48  Secondary Edu           Yes        20.0    NaN
# 4236  Female   44    Primary Edu           Yes        15.0     No
# 4237  Female   52  Secondary Edu            No         0.0     No
# 4238    Male   40   Tertiary Edu            No         0.0     No
# 4239  Female   39   Tertiary Edu           Yes        30.0     No
#
#      prevalentStroke prevalentHyp diabetes  totChol  sysBP  diaBP    BMI  \
# 0                 No           No       No    195.0  106.0   70.0  26.97
# ...

# %%
df.drop(columns=['age'],axis=1, inplace= True)

# %%
df
# Out:
#         male      education currentSmoker  cigsPerDay BPMeds prevalentStroke  \
# 0       Male      post grad            No         0.0     No              No
# 1     Female  Secondary Edu            No         0.0     No              No
# 2       Male    Primary Edu           Yes        20.0     No              No
# 3     Female   Tertiary Edu           Yes        30.0     No              No
# 4     Female   Tertiary Edu           Yes        23.0     No              No
# ...      ...            ...           ...         ...    ...             ...
# 4235  Female  Secondary Edu           Yes        20.0    NaN              No
# 4236  Female    Primary Edu           Yes        15.0     No              No
# 4237  Female  Secondary Edu            No         0.0     No              No
# 4238    Male   Tertiary Edu            No         0.0     No              No
# 4239  Female   Tertiary Edu           Yes        30.0     No              No
#
# ...

# %% [markdown]
# ## Changing the education columns

# %%
 #checking educatuon coulnm
df.education
# Out:
# 0           post grad
# 1       Secondary Edu
# 2         Primary Edu
# 3        Tertiary Edu
# 4        Tertiary Edu
#             ...
# 4235    Secondary Edu
# 4236      Primary Edu
# 4237    Secondary Edu
# 4238     Tertiary Edu
# 4239     Tertiary Edu
# Name: education, Length: 4240, dtype: object

# %%
df['education']=df['education'].apply (lambda x: 1 if x=='Primary Edu' else 2 if x=='Secondary Edu' else 3 if x== 'Tertiary Edu' else 4 )

# %%
df.head(3)
# Out:
#      male  education currentSmoker  cigsPerDay BPMeds prevalentStroke  \
# 0    Male          4            No         0.0     No              No
# 1  Female          2            No         0.0     No              No
# 2    Male          1           Yes        20.0     No              No
#
#   prevalentHyp diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0           No       No    195.0  106.0   70.0  26.97       80.0     77.0
# 1           No       No    250.0  121.0   81.0  28.73       95.0     76.0
# 2           No       No    245.0  127.5   80.0  25.34       75.0     70.0
#
#   TenYearCHD age_in_days
# 0         No  14235 days
# 1         No  16790 days
# 2         No  17520 days

# %% [markdown]
# # # changing the current smokers

# %%
# replace={'No':0, 'Yes':1}

# %%
df['currentSmoker']=df['currentSmoker'].map({'Yes':1,'No':0}) #using the map function and it takes dictionary

# %%
# df['currentSmoker'].replace('No',0)
# df['currentSmoker'].replace('Yes',1)

# %%
df.tail(10)
# Out:
#         male  education  currentSmoker  cigsPerDay BPMeds prevalentStroke  \
# 4230  Female          1              1         3.0     No              No
# 4231    Male          3              0         0.0     No              No
# 4232    Male          1              0         0.0     No              No
# 4233    Male          1              1         1.0     No              No
# 4234    Male          3              1        43.0     No              No
# 4235  Female          2              1        20.0    NaN              No
# 4236  Female          1              1        15.0     No              No
# 4237  Female          2              0         0.0     No              No
# 4238    Male          3              0         0.0     No              No
# 4239  Female          3              1        30.0     No              No
#
#      prevalentHyp diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# ...

# %%
df.head(5)
# Out:
#      male  education  currentSmoker  cigsPerDay BPMeds prevalentStroke  \
# 0    Male          4              0         0.0     No              No
# 1  Female          2              0         0.0     No              No
# 2    Male          1              1        20.0     No              No
# 3  Female          3              1        30.0     No              No
# 4  Female          3              1        23.0     No              No
#
#   prevalentHyp diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0           No       No    195.0  106.0   70.0  26.97       80.0     77.0
# 1           No       No    250.0  121.0   81.0  28.73       95.0     76.0
# 2           No       No    245.0  127.5   80.0  25.34       75.0     70.0
# 3          Yes       No    225.0  150.0   95.0  28.58       65.0    103.0
# 4           No       No    285.0  130.0   84.0  23.10       85.0     85.0
#
#   TenYearCHD age_in_days
# 0         No  14235 days
# 1         No  16790 days
# ...

# %% [markdown]
# ## checking the cigperday columns

# %%
df['cigsPerDay'].describe()
# Out:
# count    4211.000000
# mean        9.005937
# std        11.922462
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%        20.000000
# max        70.000000
# Name: cigsPerDay, dtype: float64

# %%
for i,x in enumerate (df['BPMeds']):
    print(x)
    if x =='Yes':
        df['BPMeds'][i]=1
    elif x=='No':
        df['BPMeds'][i]=0
# Out:
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# Yes
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# Yes
# No
# Yes
# No
# No
# No
# No
# nan
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# C:\Users\user\AppData\Local\Temp\ipykernel_10660\83774571.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['BPMeds'][i]=0
# C:\Users\user\AppData\Local\Temp\ipykernel_10660\83774571.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['BPMeds'][i]=1
# No
# ...

# %%
df.BPMeds.unique()
# Out:
# array([0, 1, nan], dtype=object)

# %%
df.head(5)
# Out:
#      male  education  currentSmoker  cigsPerDay BPMeds prevalentStroke  \
# 0    Male          4              0         0.0      0              No
# 1  Female          2              0         0.0      0              No
# 2    Male          1              1        20.0      0              No
# 3  Female          3              1        30.0      0              No
# 4  Female          3              1        23.0      0              No
#
#   prevalentHyp diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0           No       No    195.0  106.0   70.0  26.97       80.0     77.0
# 1           No       No    250.0  121.0   81.0  28.73       95.0     76.0
# 2           No       No    245.0  127.5   80.0  25.34       75.0     70.0
# 3          Yes       No    225.0  150.0   95.0  28.58       65.0    103.0
# 4           No       No    285.0  130.0   84.0  23.10       85.0     85.0
#
#   TenYearCHD age_in_days
# 0         No  14235 days
# 1         No  16790 days
# ...

# %%
df['prevalentStroke']=df['prevalentStroke'].apply(lambda x:1 if x=='Yes' else 0)

# %%
df[df.prevalentStroke==1] # checking /filtering where prevalent of smoke is 1
# Out:
#         male  education  currentSmoker  cigsPerDay BPMeds  prevalentStroke  \
# 255   Female          1              0         0.0      1                1
# 475     Male          3              1        15.0      0                1
# 646     Male          2              0         0.0      0                1
# 763   Female          1              0         0.0      0                1
# 1044  Female          1              0         0.0    NaN                1
# 1553    Male          1              1        15.0      0                1
# 1624  Female          1              0         0.0      0                1
# 1975    Male          1              1        20.0      0                1
# 2036  Female          2              0         0.0      0                1
# 2204    Male          2              1        20.0      0                1
# 2461    Male          1              0         0.0      0                1
# ...

# %%
df.head(3)
# Out:
#      male  education  currentSmoker  cigsPerDay BPMeds  prevalentStroke  \
# 0    Male          4              0         0.0      0                0
# 1  Female          2              0         0.0      0                0
# 2    Male          1              1        20.0      0                0
#
#   prevalentHyp diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0           No       No    195.0  106.0   70.0  26.97       80.0     77.0
# 1           No       No    250.0  121.0   81.0  28.73       95.0     76.0
# 2           No       No    245.0  127.5   80.0  25.34       75.0     70.0
#
#   TenYearCHD age_in_days
# 0         No  14235 days
# 1         No  16790 days
# 2         No  17520 days

# %%
df['diabetes']=df['diabetes'].apply(lambda x:0 if x== 'No' else 1)

# %%
df[df.diabetes==1]
# Out:
#         male  education  currentSmoker  cigsPerDay BPMeds  prevalentStroke  \
# 37      Male          1              0         0.0      0                0
# 44    Female          3              0         0.0      1                0
# 56    Female          1              1         9.0      0                0
# 66    Female          1              0         0.0      0                0
# 96    Female          4              1        20.0      0                0
# ...      ...        ...            ...         ...    ...              ...
# 4096  Female          1              0         0.0      0                0
# 4154    Male          2              0         0.0      0                0
# 4203    Male          1              1        10.0      0                0
# 4215  Female          1              0         0.0      0                0
# 4228  Female          1              0         0.0      0                0
#
# ...

# %%
for i, prevalent in enumerate (df['prevalentHyp']):
    if prevalent =='Yes':
        df['prevalentHyp'][i]=1
    elif prevalent == 'No':
        df['prevalentHyp'][i]=0
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_10660\2972571564.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['prevalentHyp'][i]=0
# C:\Users\user\AppData\Local\Temp\ipykernel_10660\2972571564.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['prevalentHyp'][i]=1

# %%
df.head(5)
# Out:
#      male  education  currentSmoker  cigsPerDay BPMeds  prevalentStroke  \
# 0    Male          4              0         0.0      0                0
# 1  Female          2              0         0.0      0                0
# 2    Male          1              1        20.0      0                0
# 3  Female          3              1        30.0      0                0
# 4  Female          3              1        23.0      0                0
#
#   prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0            0         0    195.0  106.0   70.0  26.97       80.0     77.0
# 1            0         0    250.0  121.0   81.0  28.73       95.0     76.0
# 2            0         0    245.0  127.5   80.0  25.34       75.0     70.0
# 3            1         0    225.0  150.0   95.0  28.58       65.0    103.0
# 4            0         0    285.0  130.0   84.0  23.10       85.0     85.0
#
#   TenYearCHD age_in_days
# 0         No  14235 days
# 1         No  16790 days
# ...

# %%
df[df['prevalentHyp']==1]
# Out:
#         male  education  currentSmoker  cigsPerDay BPMeds  prevalentStroke  \
# 3     Female          3              1        30.0      0                0
# 5     Female          2              0         0.0      0                0
# 8       Male          1              0         0.0      0                0
# 9       Male          1              1        30.0      0                0
# 12      Male          1              1        15.0      0                0
# ...      ...        ...            ...         ...    ...              ...
# 4230  Female          1              1         3.0      0                0
# 4231    Male          3              0         0.0      0                0
# 4232    Male          1              0         0.0      0                0
# 4233    Male          1              1         1.0      0                0
# 4238    Male          3              0         0.0      0                0
#
# ...

# %%
df.head(6)
# Out:
#      male  education  currentSmoker  cigsPerDay BPMeds  prevalentStroke  \
# 0    Male          4              0         0.0      0                0
# 1  Female          2              0         0.0      0                0
# 2    Male          1              1        20.0      0                0
# 3  Female          3              1        30.0      0                0
# 4  Female          3              1        23.0      0                0
# 5  Female          2              0         0.0      0                0
#
#   prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0            0         0    195.0  106.0   70.0  26.97       80.0     77.0
# 1            0         0    250.0  121.0   81.0  28.73       95.0     76.0
# 2            0         0    245.0  127.5   80.0  25.34       75.0     70.0
# 3            1         0    225.0  150.0   95.0  28.58       65.0    103.0
# 4            0         0    285.0  130.0   84.0  23.10       85.0     85.0
# ...

# %%
#  Checking box plot after capping
df['totChol'].plot(kind='box', grid= True)
# Out:
# <Axes: >

# %%
df.totChol.describe()
# Out:
# count    4190.000000
# mean      236.699523
# std        44.591284
# min       107.000000
# 25%       206.000000
# 50%       234.000000
# 75%       263.000000
# max       696.000000
# Name: totChol, dtype: float64

# %%
# Capping the outlires in totChols to 263 which is the 75 percentile using Lambda
df['totChol']=df['totChol'].apply (lambda x :x if x <263 else 263)

# %%
df.head(7)
# Out:
#      male  education  currentSmoker  cigsPerDay BPMeds  prevalentStroke  \
# 0    Male          4              0         0.0      0                0
# 1  Female          2              0         0.0      0                0
# 2    Male          1              1        20.0      0                0
# 3  Female          3              1        30.0      0                0
# 4  Female          3              1        23.0      0                0
# 5  Female          2              0         0.0      0                0
# 6  Female          1              0         0.0      0                0
#
#   prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0            0         0    195.0  106.0   70.0  26.97       80.0     77.0
# 1            0         0    250.0  121.0   81.0  28.73       95.0     76.0
# 2            0         0    245.0  127.5   80.0  25.34       75.0     70.0
# 3            1         0    225.0  150.0   95.0  28.58       65.0    103.0
# ...

# %%
df.totChol.describe()
# Out:
# count    4240.000000
# mean      229.171934
# std        31.597140
# min       107.000000
# 25%       206.000000
# 50%       234.000000
# 75%       263.000000
# max       263.000000
# Name: totChol, dtype: float64

# %%
df.totChol.plot(kind='box')
# Out:
# <Axes: >

# %%
import seaborn as sns

# %%
# checking the totchol adfter capping
sns.histplot(df['totChol'], kde= True)
# Out:
# <Axes: xlabel='totChol', ylabel='Count'>

# %%
# checking cigPerDay out
sns.histplot(df['cigsPerDay'], kde = True)
# Out:
# <Axes: xlabel='cigsPerDay', ylabel='Count'>

# %%
df['sysBP'].describe()
# Out:
# count    4240.000000
# mean      132.354599
# std        22.033300
# min        83.500000
# 25%       117.000000
# 50%       128.000000
# 75%       144.000000
# max       295.000000
# Name: sysBP, dtype: float64

# %%
df.sysBP.plot(kind='box')
# Out:
# <Axes: >

# %%
df.sysBP.describe()
# Out:
# count    4240.000000
# mean      132.354599
# std        22.033300
# min        83.500000
# 25%       117.000000
# 50%       128.000000
# 75%       144.000000
# max       295.000000
# Name: sysBP, dtype: float64

# %%
df['sysBP']=df['sysBP'].apply (lambda x:x if x<150 else 150)

# %%
df.head(4)
# Out:
#      male  education  currentSmoker  cigsPerDay BPMeds  prevalentStroke  \
# 0    Male          4              0         0.0      0                0
# 1  Female          2              0         0.0      0                0
# 2    Male          1              1        20.0      0                0
# 3  Female          3              1        30.0      0                0
#
#   prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0            0         0    195.0  106.0   70.0  26.97       80.0     77.0
# 1            0         0    250.0  121.0   81.0  28.73       95.0     76.0
# 2            0         0    245.0  127.5   80.0  25.34       75.0     70.0
# 3            1         0    225.0  150.0   95.0  28.58       65.0    103.0
#
#   TenYearCHD age_in_days
# 0         No  14235 days
# 1         No  16790 days
# 2         No  17520 days
# 3        Yes  22265 days

# %%
df.diaBP.describe()
# Out:
# count    4240.000000
# mean       82.897759
# std        11.910394
# min        48.000000
# 25%        75.000000
# 50%        82.000000
# 75%        90.000000
# max       142.500000
# Name: diaBP, dtype: float64

# %%
df.diaBP.plot(kind='box')
# Out:
# <Axes: >

# %%
df.head(4)
# Out:
#      male  education  currentSmoker  cigsPerDay BPMeds  prevalentStroke  \
# 0    Male          4              0         0.0      0                0
# 1  Female          2              0         0.0      0                0
# 2    Male          1              1        20.0      0                0
# 3  Female          3              1        30.0      0                0
#
#   prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0            0         0    195.0  106.0   70.0  26.97       80.0     77.0
# 1            0         0    250.0  121.0   81.0  28.73       95.0     76.0
# 2            0         0    245.0  127.5   80.0  25.34       75.0     70.0
# 3            1         0    225.0  150.0   95.0  28.58       65.0    103.0
#
#   TenYearCHD age_in_days
# 0         No  14235 days
# 1         No  16790 days
# 2         No  17520 days
# 3        Yes  22265 days

# %% [markdown]
# ## CHECKING age_in_days out

# %%
df['age_in_days']/365
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\ops\array_ops.py:165, in _na_arithmetic_op(left, right, op, is_cmp)
#     164 try:
# --> 165     result = func(left, right)
#     166 except TypeError:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\expressions.py:241, in evaluate(op, a, b, use_numexpr)
#     239     if use_numexpr:
#     240         # error: "None" not callable
# --> 241         return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     242 return _evaluate_standard(op, op_str, a, b)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\expressions.py:129, in _evaluate_numexpr(op, op_str, a, b)
#     128 if result is None:
# --> 129     result = _evaluate_standard(op, op_str, a, b)
#     131 return result
#
# ...

# %%
df['age_in_days'].strip('days') #series has no attribute strip so we need to convert to string
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[474], line 1
# ----> 1 df['age_in_days'].strip('days')
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'strip'

# %%
df['age_in_days'].str.strip('days')
# Out:
# 0       14235
# 1       16790
# 2       17520
# 3       22265
# 4       16790
#          ...
# 4235    17520
# 4236    16060
# 4237    18980
# 4238    14600
# 4239    14235
# Name: age_in_days, Length: 4240, dtype: object

# %%
df['days']=df['age_in_days'].str.strip('days')

# %%
df['days']=df['days'].astype(int) #type casting

# %%
df.head(6)
# Out:
#      male  education  currentSmoker  cigsPerDay BPMeds  prevalentStroke  \
# 0    Male          4              0         0.0      0                0
# 1  Female          2              0         0.0      0                0
# 2    Male          1              1        20.0      0                0
# 3  Female          3              1        30.0      0                0
# 4  Female          3              1        23.0      0                0
# 5  Female          2              0         0.0      0                0
#
#   prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0            0         0    195.0  106.0   70.0  26.97       80.0     77.0
# 1            0         0    250.0  121.0   81.0  28.73       95.0     76.0
# 2            0         0    245.0  127.5   80.0  25.34       75.0     70.0
# 3            1         0    225.0  150.0   95.0  28.58       65.0    103.0
# 4            0         0    263.0  130.0   84.0  23.10       85.0     85.0
# ...

# %%
df['age']=df['days']//365

# %%
df.head()
# Out:
#      male  education  currentSmoker  cigsPerDay BPMeds  prevalentStroke  \
# 0    Male          4              0         0.0      0                0
# 1  Female          2              0         0.0      0                0
# 2    Male          1              1        20.0      0                0
# 3  Female          3              1        30.0      0                0
# 4  Female          3              1        23.0      0                0
#
#   prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0            0         0    195.0  106.0   70.0  26.97       80.0     77.0
# 1            0         0    250.0  121.0   81.0  28.73       95.0     76.0
# 2            0         0    245.0  127.5   80.0  25.34       75.0     70.0
# 3            1         0    225.0  150.0   95.0  28.58       65.0    103.0
# 4            0         0    263.0  130.0   84.0  23.10       85.0     85.0
#
#   TenYearCHD age_in_days   days  age
# 0         No  14235 days  14235   39
# ...

# %%
# df.drop(columns= ['age_in_days'], axis=1, inplace= True)`

# %%
df.drop(columns=['age_in_days'],axis=1, inplace= True)

# %%
df.drop (columns=)
